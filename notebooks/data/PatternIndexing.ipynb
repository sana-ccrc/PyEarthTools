# %% [markdown]
# # Pattern Based Indexing

# %%
import pyearthtools.data

# %% [markdown]
# ## Variables

# %%
root_dir = '/PatternData'
doi = '2021-01-01T0100'

# %% [markdown]
# ## Patterns
# While `pyearthtools.data.archive` provides DataIndexes for commonly used archival datasets, `pyearthtools.data.pattern` provides a method in which to index into data sources that follow a defined pattern, and allows all of the functionality of `pyearthtools.data` with said index.
#
# As of the writing of this notebook, the following patterns are included:
# - ExpandedDate
# - DirectDate
# - ArgumentExpansion
# - Static
#
# Each are well documented, with examples in each docstring.

# %%
patternIndex = pyearthtools.data.patterns.ExpandedDate(root_dir, extension = '.nc')
patternIndex.catalog
# Out:
# 'ExpandedDate'
# ExpandedDate - pyearthtools.data.patterns.expanded_date.expanded_date
# Arguments
#   *  root_dir                 /PatternData
#   *  extension                .nc
#   *  prefix                   None

# %%
patternIndex.search(doi)
# Out:
# PosixPath('/PatternData/2021/01/01/20210101T0100.nc')

# %% [markdown]
# ### Implementation
# `pyearthtools.data.PatternIndex` provides a useful `.get` method which attempts to automatically load the discovered file, so to create a Custom Pattern, the `filesystem` and `catalog` functions may be the only needed functions.

# %%
class CustomPattern(pyearthtools.data.PatternIndex):
    def __init__(self, root_dir, transforms: pyearthtools.data.transform.Transform = None):
        self.root_dir = root_dir
        super().__init__(transforms)
        
    def filesystem(self, querytime):
        return f"{self.root_dir}/{querytime.strftime('%m/%d/%Y')}/Custom.nc"

    @property
    def catalog(self):
        return pyearthtools.data.CatalogEntry(__class__, 'CustomPattern', root_dir = self.root_dir)

# %%
CustomPattern(root_dir).search(doi)
# Out:
# '/PatternData/01/01/2021/Custom.nc'

# %%
CustomPattern(root_dir).catalog
# Out:
# 'CustomPattern'
# CustomPattern - __main__.CustomPattern
# Arguments
#   *  root_dir                 /PatternData

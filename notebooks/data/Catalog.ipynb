# %% [markdown]
# # Data Catalogue

# %%
import pyearthtools.data
import tempfile

# %% [markdown]
# ## Variables

# %%
var = '2t'
doi = '2021-01-01T0100'

# %% [markdown]
# ## Catalog
# For easy repeatability and sharing of DataIndex configurations, it is possible to create a Catalog of DataIndexes.
#
# This can then be saved and reloaded for use.
#
# Also included is a `Default_Catalog`, that exists at the top level of the package, and thus is stateful while `pyearthtools.data` is loaded.

# %%
pyearthtools.data.Default_Catalog
# Out:
# <div><svg style="position: absolute; width: 0; height: 0; overflow: hidden">
#     <defs>
#     <symbol id="icon-database" viewBox="0 0 32 32">
#     <path d="M16 0c-8.837 0-16 2.239-16 5v4c0 2.761 7.163 5 16 5s16-2.239 16-5v-4c0-2.761-7.163-5-16-5z"></path>
#     <path d="M16 17c-8.837 0-16-2.239-16-5v6c0 2.761 7.163 5 16 5s16-2.239 16-5v-6c0 2.761-7.163 5-16 5z"></path>
#     <path d="M16 26c-8.837 0-16-2.239-16-5v6c0 2.761 7.163 5 16 5s16-2.239 16-5v-6c0 2.761-7.163 5-16 5z"></path>
#     </symbol>
#     <symbol id="icon-file-text2" viewBox="0 0 32 32">
#     <path d="M28.681 7.159c-0.694-0.947-1.662-2.053-2.724-3.116s-2.169-2.030-3.116-2.724c-1.612-1.182-2.393-1.319-2.841-1.319h-15.5c-1.378 0-2.5 1.121-2.5 2.5v27c0 1.378 1.122 2.5 2.5 2.5h23c1.378 0 2.5-1.122 2.5-2.5v-19.5c0-0.448-0.137-1.23-1.319-2.841zM24.543 5.457c0.959 0.959 1.712 1.825 2.268 2.543h-4.811v-4.811c0.718 0.556 1.584 1.309 2.543 2.268zM28 29.5c0 0.271-0.229 0.5-0.5 0.5h-23c-0.271 0-0.5-0.229-0.5-0.5v-27c0-0.271 0.229-0.5 0.5-0.5 0 0 15.499-0 15.5 0v7c0 0.552 0.448 1 1 1h7v19.5z"></path>
#     <path d="M23 26h-14c-0.552 0-1-0.448-1-1s0.448-1 1-1h14c0.552 0 1 0.448 1 1s-0.448 1-1 1z"></path>
#     <path d="M23 22h-14c-0.552 0-1-0.448-1-1s0.448-1 1-1h14c0.552 0 1 0.448 1 1s-0.448 1-1 1z"></path>
#     <path d="M23 18h-14c-0.552 0-1-0.448-1-1s0.448-1 1-1h14c0.552 0 1 0.448 1 1s-0.448 1-1 1z"></path>
#     </symbol>
#     </defs>
#     </svg>
# <style>/* CSS stylesheet for displaying xarray objects in jupyterlab.
#  *
#  */
#
#  :root {
#   --catalog-font-color0: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --catalog-font-color2: var(--jp-content-font-color2, rgba(0, 0, 0, 0.54));
#   --catalog-font-color3: var(--jp-content-font-color3, rgba(0, 0, 0, 0.38));
#   --catalog-border-color: var(--jp-border-color2, #e0e0e0);
#   --catalog-disabled-color: var(--jp-layout-color3, #bdbdbd);
#   --catalog-background-color: var(--jp-layout-color0, white);
#   --catalog-background-color-row-even: var(--jp-layout-color1, white);
#   --catalog-background-color-row-odd: var(--jp-layout-color2, #cbc4c4);
# }
#
# html[theme=dark],
# body[data-theme=dark],
# body.vscode-dark {
#   --catalog-font-color0: rgba(255, 255, 255, 1);
#   --catalog-font-color2: rgba(255, 255, 255, 0.54);
#   --catalog-font-color3: rgba(255, 255, 255, 0.38);
#   --catalog-border-color: #1F1F1F;
#   --catalog-disabled-color: #515151;
#   --catalog-background-color: #111111;
#   --catalog-background-color-row-even: #111111;
#   --catalog-background-color-row-odd: #313131;
# }
#
# .catalog-wrap {
#   display: block !important;
#   min-width: 300px;
#   max-width: 700px;
# }
#
# .catalog-text-repr-fallback {
#   /* fallback to plain text repr when CSS is not injected (untrusted notebook) */
#   display: none;
# }
#
# .catalog-header {
#   padding-top: 6px;
#   padding-bottom: 6px;
#   margin-bottom: 4px;
#   border-bottom: solid 1px var(--catalog-border-color);
# }
#
# .catalog-header > div,
# .catalog-header > ul {
#   display: inline;
#   margin-top: 0;
#   margin-bottom: 0;
# }
#
# .catalog-obj-type,
# .catalog-array-name {
#   margin-left: 2px;
#   margin-right: 10px;
# }
#
# .catalog-obj-type {
#   color: var(--catalog-font-color2);
# }
#
# .catalog-sections {
#   padding-left: 0 !important;
#   display: grid;
#   grid-template-columns: 150px auto auto 1fr 20px 20px;
# }
#
# .catalog-section-item {
#   display: contents;
# }
#
# .catalog-section-item input {
#   display: none;
# }
#
# .catalog-section-item input + label {
#   color: var(--catalog-disabled-color);
# }
#
# .catalog-section-item input:enabled + label {
#   cursor: pointer;
#   color: var(--catalog-font-color2);
# }
#
# .catalog-section-item input:enabled + label:hover {
#   color: var(--catalog-font-color0);
# }
#
# .catalog-section-summary {
#   grid-column: 1;
#   color: var(--catalog-font-color2);
#   font-weight: 500;
# }
#
# .catalog-section-summary > span {
#   display: inline-block;
#   padding-left: 0.5em;
# }
#
# .catalog-section-summary-in:disabled + label {
#   color: var(--catalog-font-color2);
# }
#
# .catalog-section-summary-in + label:before {
#   display: inline-block;
#   content: '►';
#   font-size: 11px;
#   width: 15px;
#   text-align: center;
# }
#
# .catalog-section-summary-in:disabled + label:before {
#   color: var(--catalog-disabled-color);
# }
#
# .catalog-section-summary-in:checked + label:before {
#   content: '▼';
# }
#
# .catalog-section-summary-in:checked + label > span {
#   display: none;
# }
#
# .catalog-section-summary,
# .catalog-section-inline-details {
#   padding-top: 4px;
#   padding-bottom: 4px;
# }
#
# .catalog-section-inline-details {
#   grid-column: 2 / -1;
# }
#
# .catalog-section-details {
#   display: none;
#   grid-column: 1 / -1;
#   margin-bottom: 5px;
# }
#
# .catalog-section-summary-in:checked ~ .catalog-section-details {
#   display: contents;
# }
#
# .catalog-array-wrap {
#   grid-column: 1 / -1;
#   display: grid;
#   grid-template-columns: 20px auto;
# }
#
# .catalog-array-wrap > label {
#   grid-column: 1;
#   vertical-align: top;
# }
#
# .catalog-preview {
#   color: var(--catalog-font-color3);
# }
#
# .catalog-array-preview,
# .catalog-array-data {
#   padding: 0 5px !important;
#   grid-column: 2;
# }
#
# .catalog-array-data,
# .catalog-array-in:checked ~ .catalog-array-preview {
#   display: none;
# }
#
# .catalog-array-in:checked ~ .catalog-array-data,
# .catalog-array-preview {
#   display: inline-block;
# }
#
# .catalog-dim-list {
#   display: inline-block !important;
#   list-style: none;
#   padding: 0 !important;
#   margin: 0;
# }
#
# .catalog-dim-list li {
#   display: inline-block;
#   padding: 0;
#   margin: 0;
# }
#
# .catalog-dim-list:before {
#   content: '(';
# }
#
# .catalog-dim-list:after {
#   content: ')';
# }
#
# .catalog-dim-list li:not(:last-child):after {
#   content: ',';
#   padding-right: 5px;
# }
#
# .catalog-has-index {
#   font-weight: bold;
# }
#
# .catalog-var-list,
# .catalog-var-item {
#   display: contents;
# }
#
# .catalog-var-item > div,
# .catalog-var-item label,
# .catalog-var-item > .catalog-var-name span {
#   background-color: var(--catalog-background-color-row-even);
#   margin-bottom: 0;
# }
#
# .catalog-var-item > .catalog-var-name:hover span {
#   padding-right: 5px;
# }
#
# .catalog-var-list > li:nth-child(odd) > div,
# .catalog-var-list > li:nth-child(odd) > label,
# .catalog-var-list > li:nth-child(odd) > .catalog-var-name span {
#   background-color: var(--catalog-background-color-row-odd);
# }
#
# .catalog-var-name {
#   grid-column: 1;
# }
#
# .catalog-var-dims {
#   grid-column: 2;
# }
#
# .catalog-var-dtype {
#   grid-column: 3;
#   text-align: right;
#   color: var(--catalog-font-color2);
# }
#
# .catalog-var-preview {
#   grid-column: 4;
# }
#
# .catalog-index-preview {
#   grid-column: 2 / 5;
#   color: var(--catalog-font-color2);
# }
#
# .catalog-var-name,
# .catalog-var-dims,
# .catalog-var-dtype,
# .catalog-preview,
# .catalog-attrs dt {
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
#   padding-right: 10px;
# }
#
# .catalog-var-name:hover,
# .catalog-var-dims:hover,
# .catalog-var-dtype:hover,
# .catalog-attrs dt:hover {
#   overflow: visible;
#   width: auto;
#   z-index: 1;
# }
#
# .catalog-var-attrs,
# .catalog-var-data,
# .catalog-index-data {
#   display: none;
#   background-color: var(--catalog-background-color) !important;
#   padding-bottom: 5px !important;
# }
#
# .catalog-var-attrs-in:checked ~ .catalog-var-attrs,
# .catalog-var-data-in:checked ~ .catalog-var-data,
# .catalog-index-data-in:checked ~ .catalog-index-data {
#   display: block;
# }
#
# .catalog-var-data > table {
#   float: right;
# }
#
# .catalog-var-name span,
# .catalog-var-data,
# .catalog-index-name div,
# .catalog-index-data,
# .catalog-attrs {
#   padding-left: 25px !important;
# }
#
# .catalog-attrs,
# .catalog-var-attrs,
# .catalog-var-data,
# .catalog-index-data {
#   grid-column: 1 / -1;
# }
#
# dl.catalog-attrs {
#   padding: 0;
#   margin: 0;
#   display: grid;
#   grid-template-columns: 125px auto;
# }
#
# .catalog-attrs dt,
# .catalog-attrs dd {
#   padding: 0;
#   margin: 0;
#   float: left;
#   padding-right: 10px;
#   width: auto;
# }
#
# .catalog-attrs dt {
#   font-weight: normal;
#   grid-column: 1;
# }
#
# .catalog-attrs dt:hover span {
#   display: inline-block;
#   background: var(--catalog-background-color);
#   padding-right: 10px;
# }
#
# .catalog-attrs dd {
#   grid-column: 2;
#   white-space: pre-wrap;
#   word-break: break-all;
# }
#
# .catalog-icon-database,
# .catalog-icon-file-text2,
# .catalog-no-icon {
#   display: inline-block;
#   verti

# %% [markdown]
# ### Creating a New Entry
# Ultimately a catalog entry can be any function, or class, the CatalogEntry simply stores it's path, and the parameters to be passed to it upon initialisation or execution. **For reuse however, these parameters cannot be objects.**
#
# We shall show use cases using the DataIndexes here.

# %% [markdown]
# First, let's setup a basic ERA5 index as a catalog entry, and show how to use it

# %%
CatEntry = pyearthtools.data.CatalogEntry(pyearthtools.data.archive.ERA5,'ERA5', var, level = 'single')
CatEntry
# Out:
# 'ERA5'
# ERA5 - pyearthtools.data.archive.ERA5.ERA5
# Arguments
#   *  args                     ('2t',)
#   *  level                    single

# %% [markdown]
# A Catalog Entry can be called just like any other DataIndex

# %%
CatEntry(doi)
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 1, latitude: 721, longitude: 1440)
# Coordinates:
#   * longitude  (longitude) float32 -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 2021-01-01T01:00:00
# Data variables:
#     2t         (time, latitude, longitude) float32 dask.array<chunksize=(1, 253, 506), meta=np.ndarray>

# %% [markdown]
# ### Adding to a Catalog
# A catalog is a combination of a dict and list, and as such new entries can be added to it.
#
# A Catalog, CatalogEntry can easily be added together.

# %%
new_catalog = pyearthtools.data.Default_Catalog + CatEntry
new_catalog
# Out:
# ERA5 - pyearthtools.data.archive.ERA5.ERA5
# Arguments
#   *  args                     ('2t',)
#   *  level                    single

# %% [markdown]
# To then retrieve from the Catalog, simply use it's key/name

# %%
new_catalog.ERA5
# Out:
# 'ERA5'
# ERA5 - pyearthtools.data.archive.ERA5.ERA5
# Arguments
#   *  args                     ('2t',)
#   *  level                    single

# %% [markdown]
# ### DataIndex Catalogues
# All inbuilt DataIndexes provide thier own CatalogEntry accessible from `.catalog`, they can also be added/appended directly to a catalog, with the option to override the name.

# %%
era5 = pyearthtools.data.archive.ERA5(var, level = 'single')
era5.catalog
# Out:
# 'ERA5'
# ERA5 - pyearthtools.data.archive.ERA5.ERA5
# Arguments
#   *  variables                ['2t']
#   *  level                    single

# %%
new_catalog.append(era5, name = 'ERA5_DataIndex')
new_catalog
# Out:
# ERA5 - pyearthtools.data.archive.ERA5.ERA5
# Arguments
#   *  args                     ('2t',)
#   *  level                    singlepyearthtools.data.Catalog - 'Default'
#
# ERA5_DataIndex - pyearthtools.data.archive.ERA5.ERA5
# Arguments
#   *  variables                ['2t']
#   *  level                    single

# %% [markdown]
# ### Saving & Loading Catalogues
# To provide the reusability mentioned, these catalogs can be saved and reload.

# %%
with tempfile.TemporaryDirectory() as tempdir:
    tfile = f"{tempdir}/test_cat.catalog"
    new_catalog.save(tfile)
    # !cat "{tfile}"
# Out:
# {
#     "ERA5": {
#         "data_index": "pyearthtools.data.archive.ERA5.ERA5",
#         "name": "ERA5",
#         "args": [
#             "2t"
#         ],
#         "kwargs": {
#             "level": "single"
#         }
#     },
#     "ERA5_DataIndex": {
#         "data_index": "pyearthtools.data.archive.ERA5.ERA5",
#         "name": "ERA5_DataIndex",
#         "args": [],
#         "kwargs": {
#             "variables": [
#                 "2t"
#             ],
#             "level": "single"
#         }
#     }
# }

# %%
with tempfile.TemporaryDirectory() as tempdir:
    tfile = f"{tempdir}/test_cat.catalog"
    new_catalog.save(tfile)
    
    reloaded_catalog = pyearthtools.data.Catalog.load(tfile)
reloaded_catalog
# Out:
# ERA5 - pyearthtools.data.archive.ERA5.ERA5
# Arguments
#   *  args                     ('2t',)
#   *  level                    singlepyearthtools.data.Catalog -
#
# ERA5_DataIndex - pyearthtools.data.archive.ERA5.ERA5
# Arguments
#   *  variables                ['2t']
#   *  level                    single

# %%
reloaded_catalog['ERA5_DataIndex'](doi)
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 1, latitude: 721, longitude: 1440)
# Coordinates:
#   * longitude  (longitude) float32 -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 2021-01-01T01:00:00
# Data variables:
#     2t         (time, latitude, longitude) float32 dask.array<chunksize=(1, 253, 506), meta=np.ndarray>

# %% [markdown]
# # Tutorial Gallery
#
# (Please note - many of these tutorials are being migrated from a previous code version. They are being re-tested and should be corrected in the coming days). Each tutorial will be marked with its last-tested date to make it clear what state the notebooks are in. Testing is done at NCI with a data archive already established. Some notebooks also draw data from cloud hosted data sources. A subsequent update effort will make it clearer which notebooks rely on an on-disk catalogue and which ones run from cloud sources.

# %% [markdown]
# ## PyEarthTools - Tutorial Examples

# %% [markdown]
# - [Data Access at NCI](./tutorial/Interfacing_to_Data_at_NCI.ipynb)  (working as at 6/3/2025)
# - [Downloading ERA5 Data](./tutorial/Downloading_ERA5.ipynb)   (working as at 6/3/2025)
# - [Accessing ERA5 Data](./tutorial/Accessing_ERA5_Data.ipynb)   (working as at 6/3/2025)
# - [Introduction to Pipelines](./tutorial/Data_Pipelines.ipynb)   (working as at 6/3/2025)
# - [End-to-end CNN Training Example](./tutorial/CNN_model_training.ipynb)   (working as at 6/3/2025)
# - [Working with Multiple Data Sources](./tutorial/MultipleSources.ipynb)  (working as at 14/3/2025)

# %% [markdown]
# ## PyEarthTools - Data Module

# %% [markdown]
# - [Basic Data Indexing](./data/Basic_Indexing.ipynb)   (working as at 6/3/2025)
# - [Retrieving Single Samples](./data/SingleIndexing.ipynb)  (working as at 6/3/2025)
# - [Complex Time Series Retrieval](./data/GettingComplexSeries.ipynb)  (working as at 6/3/2025)
# - [Using Built-In Operations](./data/UsingTheInBuiltOperations.ipynb)  (working as at 13/3/2025)
# - [Applying Data Transforms](./data/Transforms.ipynb)  (working as at 13/3/2025)
# - [Region Cutting](./data/RegionCutting.ipynb)  (working as at 13/3/2025)
# - [Custom Data Index](./data/CustomDataIndex.ipynb)
# - [The Data Catalog](./data/Catalog.ipynb)
# - [Pattern Indexing](./data/PatternIndexing.ipynb)

# %% [markdown]
# ## PyEarthTools - Pipeline Module

# %% [markdown]
# - [Pipeline Basics](./pipeline/Basics.ipynb)  (working as at 14/3/2025)
# - [Pipeline Operations](./pipeline/Operations.ipynb)  (working as at 14/3/2025)
# - [Pipeline Modifications](./pipeline/Modifications.ipynb)  (mostly working, with minor required fixes noted, as as at 14/3/2025)
# - [Pipeline Branching](./pipeline/Branching.ipynb)  (working as at 14/3/2025)

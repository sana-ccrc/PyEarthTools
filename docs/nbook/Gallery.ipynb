# %% [markdown]
# # Tutorial Gallery
#
# (Please note - many of these tutorials are being migrated from a previous code version. They are being re-tested and should be corrected in the coming days). Each tutorial will be marked with its last-tested date to make it clear what state the notebooks are in. Testing is done at NCI with a data archive already established. Some notebooks also draw data from cloud hosted data sources. A subsequent update effort will make it clearer which notebooks rely on an on-disk catalogue and which ones run from cloud sources.

# %% [markdown]
# ## PyEarthTools - Tutorial Examples

# %% [markdown]
# - [Data Access at NCI](./tutorial/1a_Interfacing_to_Data_at_NCI.ipynb)  (working at at 6/3/2025)
# - [Downloading ERA5 Data](./tutorial/1b_Downloading_ERA5.ipynb)   (working at at 6/3/2025)
# - [Accessing ERA5 Data](./tutorial/1c_Accessing_ERA5_Data.ipynb)   (working at at 6/3/2025)
# - [Introduction to Pipelines](./tutorial/2_Data_Pipelines.ipynb)   (working at at 6/3/2025)
# - [End-to-end CNN Training Example](./tutorial/3_CNN_model_training.ipynb)   (working at at 6/3/2025)

# %% [markdown]
# ## PyEarthTools - Data Module

# %% [markdown]
# - [Basic Data Indexing](./data/1-Basic_Indexing.ipynb)   (working at at 6/3/2025)
# - [Retrieving Single Samples](./data/2-SingleIndexing.ipynb)  (working at 6/3/2025)
# - [Complex Time Series Retrieval](./data/3-GettingComplexSeries.ipynb)  (working at 6/3/2025)
# - [Using Built-In Operations](./data/4-UsingTheInBuiltOperations.ipynb)
# - [Applying Data Transforms](./data/5-Transforms.ipynb)
# - [Region Cutting](./data/6-RegionCutting.ipynb)
# - [Custom Data Index](./data/7-CustomDataIndex.ipynb)
# - [The Data Catalog](./data/8-Catalog.ipynb)
# - [Pattern Indexing](./data/9-PatternIndexing.ipynb)

# %% [markdown]
# ## PyEarthTools - Pipeline Module

# %% [markdown]
# - [Pipeline Basics](./pipeline/1-Basics.ipynb)
# - [Pipeline Operations](./pipeline/2-Operations.ipynb)
# - [Pipeline Modifications](./pipeline/3-Modifications.ipynb)
# - [Pipeline Branching](./pipeline/4-Branching.ipynb)
